# %%
import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics
import seaborn as sns
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
PAGE_QUERIES = 52
job_data = []

for page_num in range(1, PAGE_QUERIES + 1):
    r = requests.get('https://www.arbeitnow.com/api/job-board-api', params={'page': page_num})
    job_data.extend(r.json()['data'])

# %%
# From https://stackoverflow.com/questions/328356/extracting-text-from-html-file-using-python
def cleanDescription(html):
    soup = BeautifulSoup(html, features = "html.parser")

    for script in soup(["script","style"]):
        script.extract()
    
    text = soup.get_text()

    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    return '\n'.join(chunk for chunk in chunks if chunk)

def cleanStrList(list):
    for i, e in enumerate(list):
        list[i] = str.lower(e)
    return sorted(list)

# %%
labels = list(job_data[0].keys()) # Get names of column labels

df = pd.DataFrame(job_data, columns=labels)
df['description'] = df['description'].apply(cleanDescription)
df['tags'] = df['tags'].apply(cleanStrList)
df['job_types'] = df['job_types'].apply(cleanStrList)

df
# Out:
#                                                    slug  \
# 0     werkstudent-in-im-bereich-datamanagement-bensh...
# 1                     graphics-designer-seevetal-423717
# 2     kopie-von-werkstudent-praktikant-advertiser-ma...
# 3     working-student-publisher-management-berlin-52191
# 4            senior-recruiter-all-genders-munich-221833
# ...                                                 ...
# 5195         senior-python-developer-in-qa-berlin-21047
# 5196               commercial-manager-cee-berlin-275097
# 5197  alltagsbegleitung-alltagsbetreuung-in-freiburg...
# 5198  elektronikentwickler-quantensensorik-iv-ludwig...
# 5199  entwicklungsingenieur-fur-digital-verifikation...
#
#                      company_name  \
# 0                  Preventis GmbH
# 1                   Trendt Vision
# 2     mrge - commerce advertising
# 3     mrge - commerce advertising
# 4                     Ray Sono AG
# ...                           ...
# 5195               Veeam Software
# 5196                         Omio
# 5197       European Homecare GmbH
# 5198                  Bosch Group
# 5199                  Bosch Group
#
#                                                   title  \
# 0      Werkstudent/in im Bereich Datamanagement (m/w/d)
# 1                             Graphics Designer (m/w/d)
# 2     Kopie von Werkstudent/Praktikant Advertiser Ma...
# 3          Working Student Publisher Management (m/f/d)
# 4                      (Senior) Recruiter (all genders)
# ...                                                 ...
# 5195                      Senior Python Developer in QA
# 5196                            Commercial Manager, CEE
# 5197  Alltagsbegleitung/Alltagsbetreuung (m/w/d) in ...
# 5198    Elektronikentwickler Quantensensorik (w/m/div.)
# 5199  Entwicklungsingenieur für Digital Verifikation...
#
#                                             description  remote  \
# 0     Du willst in einem global ausgerichteten deuts...   False
# 1     Aufgaben\n- Creating graphics/photo collages\n...   False
# 2     Auf der Suche nach einer spannenden Herausford...   False
# 3     Looking for an exciting challenge?\nJoin us on...   False
# 4     Deine Aufgaben bei uns\nAls (Senior) Recruiter...   False
# ...                                                 ...     ...
# 5195  Company DescriptionThe Veeam Quality Assurance...   False
# 5196  Company DescriptionAbout OmioDriven by our tea...   False
# 5197  Company DescriptionDie European Homecare GmbH ...   False
# 5198  Company DescriptionBei Bosch gestalten wir Zuk...   False
# 5199  Company DescriptionBei Bosch gestalten wir Zuk...   False
#
#                                                     url  \
# 0     https://www.arbeitnow.com/jobs/companies/preve...
# 1     https://www.arbeitnow.com/jobs/companies/trend...
# 2     https://www.arbeitnow.com/jobs/companies/mrge-...
# 3     https://www.arbeitnow.com/jobs/companies/mrge-...
# 4     https://www.arbeitnow.com/jobs/companies/ray-s...
# ...                                                 ...
# 5195  https://www.arbeitnow.com/jobs/companies/veeam...
# 5196  https://www.arbeitnow.com/jobs/companies/omio/...
# 5197  https://www.arbeitnow.com/jobs/companies/europ...
# 5198  https://www.arbeitnow.com/jobs/companies/bosch...
# 5199  https://www.arbeitnow.com/jobs/companies/bosch...
#
#                                         tags                     job_types  \
# 0                  [database administration]             [working student]
# 1        [industrial design, product design]  [professional / experienced]
# 2              [marketing and communication]  [berufseinstieg, internship]
# 3              [marketing and communication]           [entry, internship]
# 4                                       [hr]              [berufserfahren]
# ...                                      ...                           ...
# 5195  [computer software, quality assurance]       [full time, mid-senior]
# 5196        [business development, internet]       [full time, mid-senior]
# 5197  [civic and social organization, other]        [associate, full time]
# 5198               [automotive, engineering]        [associate, full time]
# 5199               [automotive, engineering]        [associate, full time]
#
#                   location  created_at
# 0                 Bensheim  1683654545
# 1                 Seevetal  1683654545
# 2                   Berlin  1683654545
# 3                   Berlin  1683654545
# 4                   Munich  1683654545
# ...                    ...         ...
# 5195                Berlin  1683204730
# 5196                Berlin  1683204730
# 5197  Freiburg im Breisgau  1683204730
# 5198           Ludwigsburg  1683204730
# 5199            Reutlingen  1683204730
#
# [5200 rows x 10 columns]

# %%
tags_count = df['tags'].explode().value_counts().to_dict() # Occurrences of each tag
job_types_count = df['job_types'].explode().value_counts().to_dict() # Occurrences of each job type

# %%
similarity_weights = {
    "tags": 7,
    "job_type": 7,
    "location": 1,
    "remote": 1,
    "title": 3
}

similarity_total_weight = sum(similarity_weights.values())

# %%
# Code from https://towardsdatascience.com/comparing-documents-with-similarity-metrics-e486bc678a7d
# returns the cosine similarity value of the two given texts
def compute_cosine_similarity(text1, text2):
    
    # stores text in a list
    list_text = [text1, text2]
    
    # converts text into vectors with the TF-IDF 
    vectorizer = TfidfVectorizer(stop_words='english')
    vectorizer.fit_transform(list_text)
    tfidf_text1, tfidf_text2 = vectorizer.transform([list_text[0]]), vectorizer.transform([list_text[1]])
    
    # computes the cosine similarity
    cs_score = cosine_similarity(tfidf_text1, tfidf_text2)
    
    return np.round(cs_score[0][0],2)

def compute_jaccard(list1, list2):
    return len(list(set(list1) & set(list2)))/len(set(list1) | set(list2)) if len(set(list1) | set(list2)) != 0 else 1

# %%
target_id = 2047
target_obj = df.iloc[target_id]
target_obj
# Out:
# slug                     customer-care-coordinator-cologne-210316
# company_name                                              Eurowag
# title                           Customer Care Coordinator (m/w/d)
# description     Company DescriptionEurowag wurde vor etwas meh...
# remote                                                      False
# url             https://www.arbeitnow.com/jobs/companies/eurow...
# tags            [customer service, information technology and ...
# job_types                                      [entry, full time]
# location                                                  Cologne
# created_at                                             1683535923
# Name: 2047, dtype: object

# %%
def getSimilarJobs(target_id, similarity_weights=similarity_weights, df=df, n_similar=10):
    job_similarity = []
    target_obj = df.iloc[target_id]
    similarity_total_weight = sum(similarity_weights.values())

    for job_id, job_obj in df.iterrows():
        if target_id == job_id:
            continue

        tag_jaccard = compute_jaccard(target_obj["tags"], job_obj["tags"])
        job_type_jaccard = compute_jaccard(target_obj["job_types"], job_obj["job_types"])
        location_sim = 1 if target_obj["location"] == job_obj["location"] else 0
        remote_sim = 1 if target_obj["remote"] == job_obj["remote"] else 0
        title_cos = compute_cosine_similarity(target_obj['title'], job_obj['title'])

        similarity = 0
        for weight, val in zip(similarity_weights.values(), [tag_jaccard, job_type_jaccard, location_sim, remote_sim, title_cos]):
            similarity += weight * val

        job_similarity.append({
            "job": job_id,
            "similarity": similarity/similarity_total_weight
        })
    
    similarity_df = pd.DataFrame(job_similarity, columns=["job", "similarity"])
    return df.iloc[list(similarity_df.nlargest(n_similar, 'similarity').index)].join(similarity_df.nlargest(n_similar, 'similarity')['similarity'])

# %%
df.iloc[target_id]
# Out:
# slug                     customer-care-coordinator-cologne-210316
# company_name                                              Eurowag
# title                           Customer Care Coordinator (m/w/d)
# description     Company DescriptionEurowag wurde vor etwas meh...
# remote                                                      False
# url             https://www.arbeitnow.com/jobs/companies/eurow...
# tags            [customer service, information technology and ...
# job_types                                      [entry, full time]
# location                                                  Cologne
# created_at                                             1683535923
# Name: 2047, dtype: object

# %%
getSimilarJobs(target_id, similarity_weights, df, 10)
# Out:
#                                                    slug  \
# 1520            teamleiter-customer-care-iv-berlin-5615
# 448   german-speaking-in-house-recruiter-cologne-344052
# 5131  abercrombie-fitch-vollzeit-key-holder-zweibruc...
# 433   customer-service-specialist-english-f-m-d-berl...
# 125   engenheiro-de-sistemas-automoveis-h-m-hamburg-...
# 592   callcenter-agent-in-voll-oder-teilzeit-bochum-...
# 994   ingenieur-systeme-junior-all-gender-hamburg-72570
# 1187  empfangsmitarbeiter-miwid-bergisch-gladbach-49...
# 1475           technical-trainer-mulheim-karlich-202966
# 1517          teamleiter-kundenservice-iv-berlin-312895
#
#                       company_name  \
# 1520                   Bosch Group
# 448                         Verisk
# 5131  Abercrombie and Fitch Stores
# 433                           Omio
# 125                          ALTEN
# 592                    DelPro GmbH
# 994                          ALTEN
# 1187               Miltenyi Biotec
# 1475                         Tomra
# 1517                   Bosch Group
#
#                                                   title  \
# 1520                Teamleiter Customer Care (w/m/div.)
# 448          German Speaking In-House Recruiter (m/w/d)
# 5131  Abercrombie & Fitch - Vollzeit Key Holder (m/w...
# 433   Customer Service Specialist - English (f / m /...
# 125             Engenheiro de sistemas automóveis (H/M)
# 592    Callcenter Agent (m/w/d) in Voll-, oder Teilzeit
# 994               Ingénieur système junior (all gender)
# 1187                        Empfangsmitarbeiter (mIwId)
# 1475                          Technical Trainer (m/w/d)
# 1517                Teamleiter Kundenservice (w/m/div.)
#
#                                             description  remote  \
# 1520  Company DescriptionMöchtest Du Deine Ideen in ...   False
# 448   Company DescriptionWe help the world see new p...   False
# 5131  Company DescriptionDas Unternehmen  Abercrombi...   False
# 433   Company DescriptionAt Omio, we take a unique a...   False
# 125   Company DescriptionALTEN é uma empresa líder e...   False
# 592   Company DescriptionDie DelPro GmbH ist ein Rec...   False
# 994   Company DescriptionNous sommes les concepteurs...   False
# 1187  Company DescriptionJoin us in shaping the futu...   False
# 1475  Company DescriptionTOMRA Recycling entwickelt ...   False
# 1517  Company DescriptionMöchtest Du Deine Ideen in ...   False
#
#                                                     url  \
# 1520  https://www.arbeitnow.com/jobs/companies/bosch...
# 448   https://www.arbeitnow.com/jobs/companies/veris...
# 5131  https://www.arbeitnow.com/jobs/companies/aberc...
# 433   https://www.arbeitnow.com/jobs/companies/omio/...
# 125   https://www.arbeitnow.com/jobs/companies/alten...
# 592   https://www.arbeitnow.com/jobs/companies/delpr...
# 994   https://www.arbeitnow.com/jobs/companies/alten...
# 1187  https://www.arbeitnow.com/jobs/companies/milte...
# 1475  https://www.arbeitnow.com/jobs/companies/tomra...
# 1517  https://www.arbeitnow.com/jobs/companies/bosch...
#
#                                                    tags  \
# 1520  [customer service, information technology and ...
# 448   [human resources, information technology and s...
# 5131                         [customer service, retail]
# 433                        [customer service, internet]
# 125   [engineering, information technology and servi...
# 592                  [customer service, legal services]
# 994   [engineering, information technology and servi...
# 1187                  [biotechnology, customer service]
# 1475  [customer service, information technology and ...
# 1517  [customer service, information technology and ...
#
#                     job_types           location  created_at  similarity
# 1520   [associate, full time]             Berlin  1683550328    0.608596
# 448        [entry, full time]            Cologne  1683636731    0.596491
# 5131       [entry, full time]        Zweibrücken  1683204742    0.596491
# 433        [entry, full time]             Berlin  1683636733    0.570702
# 125        [entry, full time]            Hamburg  1683651138    0.543860
# 592        [entry, full time]             Bochum  1683629534    0.543860
# 994        [entry, full time]            Hamburg  1683615122    0.543860
# 1187       [entry, full time]  Bergisch Gladbach  1683557542    0.543860
# 1475  [full time, mid-senior]    Mülheim-Kärlich  1683550330    0.543860
# 1517   [associate, full time]             Berlin  1683550328    0.543860

# %%
df.iloc[1458]
# Out:
# slug            sicherheitsmitarbeiter-fur-klinikum-in-wittena...
# company_name               Global Protect Sicherheitsdienste GmbH
# title           Sicherheitsmitarbeiter (m/w/d) für Klinikum in...
# description     Company DescriptionGLOBAL PROTECT ist ein zert...
# remote                                                      False
# url             https://www.arbeitnow.com/jobs/companies/globa...
# tags                         [other, security and investigations]
# job_types                                  [associate, full time]
# location                                                   Berlin
# created_at                                             1683550330
# Name: 1458, dtype: object

# %%
getSimilarJobs(1458, similarity_weights, df, 10)
# Out:
#                                                    slug  \
# 1456  sicherheitsmitarbeiter-fur-klinikum-in-lichter...
# 1463  sicherheitsmitarbeiter-fur-wohnheim-in-mariend...
# 1466  sicherheitskraft-fur-gesundheitszentrum-berlin...
# 825   sicherheitsmitarbeiter-fur-objektschutz-berlin...
# 837         sicherheitsmitarbeiter-fur-drv-berlin-46916
# 1232  sicherheitsmitarbeiter-fur-centerbewachung-ber...
# 836   sicherheitsmitarbeiter-fur-das-bundesamt-berli...
# 903   sicherheitsmitarbeiter-fur-alba-recyclinghof-b...
# 1458  sicherheitsmitarbeiter-fur-klinikum-in-wittena...
# 1459  sicherheitsmitarbeiter-fur-wohnheim-in-wedding...
#
#                                 company_name  \
# 1456  Global Protect Sicherheitsdienste GmbH
# 1463  Global Protect Sicherheitsdienste GmbH
# 1466  Global Protect Sicherheitsdienste GmbH
# 825                      flash-security GmbH
# 837                      flash-security GmbH
# 1232                      Süss Security GmbH
# 836                      flash-security GmbH
# 903                     Skytec Security GmbH
# 1458  Global Protect Sicherheitsdienste GmbH
# 1459  Global Protect Sicherheitsdienste GmbH
#
#                                                   title  \
# 1456  Sicherheitsmitarbeiter (m/w/d) für Klinikum in...
# 1463  Sicherheitsmitarbeiter (m/w/d) für Wohnheim in...
# 1466    Sicherheitskraft (m/w/d) für Gesundheitszentrum
# 825     Sicherheitsmitarbeiter (m/w/d) für Objektschutz
# 837              Sicherheitsmitarbeiter (m/w/d) für DRV
# 1232  Sicherheitsmitarbeiter (m/w/d) für Centerbewac...
# 836    Sicherheitsmitarbeiter (m/w/d) für das Bundesamt
# 903   Sicherheitsmitarbeiter (m/w/d) für ALBA-Recycl...
# 1458  Sicherheitsmitarbeiter (m/w/d) für Klinikum in...
# 1459  Sicherheitsmitarbeiter (m/w/d) für Wohnheim in...
#
#                                             description  remote  \
# 1456  Company DescriptionGLOBAL PROTECT ist ein zert...   False
# 1463  Company DescriptionGLOBAL PROTECT ist ein zert...   False
# 1466  Company DescriptionGLOBAL PROTECT ist ein zert...   False
# 825   Company DescriptionWIR. SICHERN. BERLIN. flash...   False
# 837   Company DescriptionSkytec Security GmbH steht ...   False
# 1232  Company DescriptionBereits seit 1991 entwickel...   False
# 836   Company DescriptionWIR. SICHERN. BERLIN. flash...   False
# 903   Company DescriptionSkytec Security GmbH steht ...   False
# 1458  Company DescriptionGLOBAL PROTECT ist ein zert...   False
# 1459  Company DescriptionGLOBAL PROTECT ist ein zert...   False
#
#                                                     url  \
# 1456  https://www.arbeitnow.com/jobs/companies/globa...
# 1463  https://www.arbeitnow.com/jobs/companies/globa...
# 1466  https://www.arbeitnow.com/jobs/companies/globa...
# 825   https://www.arbeitnow.com/jobs/companies/flash...
# 837   https://www.arbeitnow.com/jobs/companies/flash...
# 1232  https://www.arbeitnow.com/jobs/companies/suss-...
# 836   https://www.arbeitnow.com/jobs/companies/flash...
# 903   https://www.arbeitnow.com/jobs/companies/skyte...
# 1458  https://www.arbeitnow.com/jobs/companies/globa...
# 1459  https://www.arbeitnow.com/jobs/companies/globa...
#
#                                       tags               job_types location  \
# 1456  [other, security and investigations]  [associate, full time]   Berlin
# 1463  [other, security and investigations]  [associate, full time]   Berlin
# 1466  [other, security and investigations]  [associate, full time]   Berlin
# 825   [other, security and investigations]  [associate, full time]   Berlin
# 837   [other, security and investigations]  [associate, full time]   Berlin
# 1232  [other, security and investigations]  [associate, full time]   Berlin
# 836   [other, security and investigations]  [associate, full time]   Berlin
# 903   [other, security and investigations]  [associate, full time]   Berlin
# 1458  [other, security and investigations]  [associate, full time]   Berlin
# 1459  [other, security and investigations]  [associate, full time]   Berlin
#
#       created_at  similarity
# 1456  1683550330    0.936842
# 1463  1683550330    0.936842
# 1466  1683550330    0.936842
# 825   1683622330    0.906842
# 837   1683622330    0.906842
# 1232  1683557533    0.906842
# 836   1683622330    0.895789
# 903   1683622322    0.895789
# 1458  1683550330    0.895789
# 1459  1683550330    0.895789

# %%
df.iloc[5091]
# Out:
# slug            auszubildender-zum-steuerfachangestellten-stad...
# company_name                  LTG Steuerberatungsgesellschaft mbH
# title           Auszubildender zum Steuerfachangestellten (m/w/d)
# description     Leidenschaftlich. Transparent. Ganzheitlich.\n...
# remote                                                      False
# url             https://www.arbeitnow.com/jobs/companies/ltg-s...
# tags                                                [tax advisor]
# job_types                                                      []
# location                                                    Stade
# created_at                                             1683208144
# Name: 5091, dtype: object

# %%
getSimilarJobs(5091, similarity_weights, df, 10)
# Out:
#                                                    slug  \
# 5087  auszubildender-zum-steuerfachangestellten-hamb...
# 5089  auszubildender-zum-steuerfachangestellten-rote...
# 5090  auszubildender-zum-steuerfachangestellten-otte...
# 5092  auszubildender-zum-steuerfachangestellten-in-f...
# 5082  steuerberater-oder-steuerberateranwarter-alle-...
# 5093  auszubildender-zum-steuerfachangestellten-droc...
# 5101    quereinstieg-als-steuerfachkraft-hamburg-465918
# 5108  steuerfachkraft-steuerfachangestellter-steuerf...
# 1088  23082-bilanzbuchhalter-vollzeit-oder-teilzeit-...
# 1420            steuerfachwirt-sozialwesen-essen-127395
#
#                                company_name  \
# 5087    LTG Steuerberatungsgesellschaft mbH
# 5089    LTG Steuerberatungsgesellschaft mbH
# 5090    LTG Steuerberatungsgesellschaft mbH
# 5092    LTG Steuerberatungsgesellschaft mbH
# 5082    LTG Steuerberatungsgesellschaft mbH
# 5093    LTG Steuerberatungsgesellschaft mbH
# 5101    LTG Steuerberatungsgesellschaft mbH
# 5108    LTG Steuerberatungsgesellschaft mbH
# 1088  Sabine Lechler GmbH Personal.Beratung
# 1420                               JobAtlas
#
#                                                   title  \
# 5087  Auszubildender zum Steuerfachangestellten (m/w/d)
# 5089  Auszubildender zum Steuerfachangestellten (m/w/d)
# 5090  Auszubildender zum Steuerfachangestellten (m/w/d)
# 5092  Auszubildender zum Steuerfachangestellten (m/w...
# 5082  Steuerberater oder Steuerberateranwärter (alle...
# 5093  Auszubildender zum Steuerfachangestellten (m/w/d)
# 5101           Quereinstieg als Steuerfachkraft (m/w/d)
# 5108  Steuerfachkraft (Steuerfachangestellter, Steue...
# 1088  23082 Bilanzbuchhalter (m/w/d) Vollzeit oder T...
# 1420               Steuerfachwirt (m/w/d) - Sozialwesen
#
#                                             description  remote  \
# 5087  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 5089  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 5090  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 5092  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 5082  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 5093  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 5101  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 5108  Leidenschaftlich. Transparent. Ganzheitlich.\n...   False
# 1088  Für unseren Kunden, ein Beratungsunternehmen f...   False
# 1420  Organisation und Finanzen sind Dein Ding? Dann...   False
#
#                                                     url           tags  \
# 5087  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 5089  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 5090  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 5092  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 5082  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 5093  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 5101  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 5108  https://www.arbeitnow.com/jobs/companies/ltg-s...  [tax advisor]
# 1088  https://www.arbeitnow.com/jobs/companies/sabin...  [tax advisor]
# 1420  https://www.arbeitnow.com/jobs/companies/jobat...  [tax advisor]
#
#                              job_types     location  created_at  similarity
# 5087                                []      Hamburg  1683208144    0.947368
# 5089                                []    Rotenburg  1683208144    0.947368
# 5090                                []   Otterndorf  1683208144    0.947368
# 5092  [apprenticeship, berufseinstieg]     Freiburg  1683208144    0.947368
# 5082                                []        Stade  1683208144    0.842105
# 5093                                []  Drochtersen  1683208144    0.842105
# 5101                                []      Hamburg  1683208144    0.842105
# 5108                                []   Otterndorf  1683208144    0.842105
# 1088                                []    Nuremberg  1683568143    0.789474
# 1420                                []        Essen  1683553745    0.789474

# %%
df.iloc[18]
# Out:
# slug            helpdesk-agent-it-everyone-is-welcome-2nd-leve...
# company_name                               Sirius Facilities GmbH
# title           Helpdesk Agent IT (everyone is welcome) 2nd Le...
# description     Deine Aufgaben\nDu unterstützt den Bereich USE...
# remote                                                      False
# url             https://www.arbeitnow.com/jobs/companies/siriu...
# tags                                       [software development]
# job_types                                        [berufserfahren]
# location                                                   Berlin
# created_at                                             1683654545
# Name: 18, dtype: object

# %%
tags_count, job_types_count
# Out:
# ({'remote': 963,
#   'information technology and services': 951,
#   'information technology': 838,
#   'engineering': 541,
#   'sales': 525,
#   'retail': 454,
#   'computer software': 448,
#   'other': 409,
#   'customer service': 252,
#   'automotive': 233,
#   'healthcare services': 204,
#   'medical and health': 178,
#   'it': 173,
#   'it software': 171,
#   'marketing and communication': 150,
#   'management': 148,
#   'finance': 145,
#   'tax advisor': 126,
#   'sales and business development': 114,
#   'software development': 103,
#   'security and investigations': 98,
#   'project and program management': 80,
#   'marketing and product': 74,
#   'hr': 73,
#   'project management': 67,
#   'electrical and electronic manufacturing': 59,
#   'transport': 59,
#   'human resources': 57,
#   'training and instruction': 57,
#   'production': 53,
#   'cosmetics': 53,
#   'logistics and transportation': 51,
#   'accounting and finance': 49,
#   'team leader': 49,
#   'recruitment and selection': 47,
#   'administrative and clerical': 47,
#   'biotechnology': 46,
#   'customer support and client care': 46,
#   'energy': 46,
#   'wholesale': 43,
#   'consulting': 42,
#   'information services': 40,
#   'marketing': 39,
#   'food services and hospitality': 39,
#   'gambling and casinos': 38,
#   'civil engineering': 37,
#   'hospitality': 37,
#   'mechanical or industrial engineering': 35,
#   'facilities services': 32,
#   'building construction and skilled trades': 31,
#   'product management': 30,
#   'financial services': 29,
#   'system and network administration': 28,
#   'education': 28,
#   'hospital and health care': 28,
#   'controlling': 24,
#   'installation and maintenance repair': 24,
#   'health care provider': 23,
#   'creative and design': 22,
#   'internet': 21,
#   'food and beverage': 21,
#   'analyst': 20,
#   'quality assurance': 20,
#   'advertising and pr services': 20,
#   'supply chain': 19,
#   'payroll accounting': 19,
#   'production and operations': 19,
#   'online marketing': 18,
#   'business and strategic development': 18,
#   'business operations': 18,
#   'real estate': 18,
#   'engineering services': 17,
#   'marketing and advertising': 17,
#   'packaging and containers': 16,
#   'business services': 15,
#   'development': 15,
#   'administrative': 15,
#   'business development': 14,
#   'oil and energy': 14,
#   'administration': 13,
#   'helpdesk': 13,
#   'public relations': 13,
#   'apparel and fashion': 13,
#   'excel': 13,
#   'research': 13,
#   'public safety': 13,
#   'construction': 12,
#   'renewables and environment': 12,
#   'semiconductors': 11,
#   'travel': 11,
#   'tracer': 11,
#   'medical device': 11,
#   'graphic arts and communication design': 11,
#   'hotels': 11,
#   'social media manager': 10,
#   'marketing manager': 10,
#   'accounting': 10,
#   'business analyst': 9,
#   'personal care': 9,
#   'personnel specialist': 9,
#   'web development': 9,
#   'corporate communication': 9,
#   'purchasing': 9,
#   'airlines/aviation': 9,
#   'nonprofit': 9,
#   'legal': 9,
#   'rental services': 9,
#   'publishing': 8,
#   'quality management': 8,
#   'editorial and writing': 8,
#   'inspection': 8,
#   'applications administration': 8,
#   'azure': 8,
#   'it security': 8,
#   'trade export': 8,
#   'chemicals': 8,
#   'crm': 7,
#   'sap': 7,
#   'event marketing': 7,
#   'strategy/planning': 7,
#   'entertainment': 7,
#   'transportation/trucking/railroad': 7,
#   'management and consulting': 7,
#   'analytics': 7,
#   'computer and network security': 6,
#   'aerospace': 6,
#   'aws': 6,
#   'onboarding': 6,
#   'sql': 6,
#   'art/creative': 6,
#   'food production': 6,
#   'sports': 6,
#   'b2b': 6,
#   'medical devices': 6,
#   'restaurant': 6,
#   'manufacturing': 6,
#   'saas': 5,
#   'auditor': 5,
#   'sporting goods': 5,
#   'staffing and recruiting': 5,
#   'devops': 5,
#   'mechatronic engineering': 5,
#   'pharmaceuticals': 5,
#   'hgb': 5,
#   'architecture': 5,
#   'accounting/auditing': 5,
#   'environmental services': 5,
#   'communication skills': 5,
#   'javascript': 5,
#   'leisure and travel': 5,
#   'distribution marketing': 5,
#   'quality assurance and saftey': 5,
#   'general business': 5,
#   'science': 5,
#   'media': 5,
#   'scrum': 4,
#   'farming': 4,
#   'construction residential': 4,
#   'account management': 4,
#   'banking': 4,
#   'business unit management': 4,
#   'css': 4,
#   'accounts receivable': 4,
#   'telecommunications': 4,
#   'department': 4,
#   'civic and social organization': 4,
#   'industrial automation': 4,
#   'supermarkets': 4,
#   'screen and web design': 4,
#   'ifrs': 4,
#   'mining and metals': 4,
#   'defense and space': 4,
#   'market research': 4,
#   'data scientist': 4,
#   'google analytics': 4,
#   'process management': 4,
#   'r and d and science': 4,
#   'postgresql': 3,
#   'jenkins': 3,
#   'seo': 3,
#   'consumer goods': 3,
#   'media production': 3,
#   'kubernetes': 3,
#   'docker': 3,
#   'itil': 3,
#   'ux': 3,
#   'less': 3,
#   'marketing assistant': 3,
#   'datev': 3,
#   'logistics and supply chain': 3,
#   'design': 3,
#   'c#': 3,
#   'textiles': 3,
#   'machinery': 3,
#   'pricing': 3,
#   'information systems': 3,
#   'analytical skills': 2,
#   'process engineering': 2,
#   'confluence': 2,
#   'audits': 2,
#   'git': 2,
#   'accounts payable': 2,
#   'firewall': 2,
#   'startups': 2,
#   'insurance products': 2,
#   'statistics': 2,
#   'budgeting': 2,
#   'python': 2,
#   'kpis': 2,
#   'html': 2,
#   'distribution': 2,
#   'e-commerce': 2,
#   'professional training': 2,
#   'data analysis': 2,
#   'analysis': 2,
#   'erp': 2,
#   'content marketing': 2,
#   'jira': 2,
#   'finance and accounting': 2,
#   'clothing': 2,
#   'typescript': 2,
#   'strategic marketing': 2,
#   'chief executives': 2,
#   'insurance': 2,
#   'automation engineering': 2,
#   'technical documentation': 2,
#   'computer services': 2,
#   'directors': 2,
#   'apache kafka': 2,
#   'music': 2,
#   'human resources manager': 2,
#   'sap/erp consulting': 2,
#   'furniture': 2,
#   'payroll': 2,
#   'ui': 2,
#   'industrial engineer': 2,
#   'medical practice': 2,
#   'writing/editing': 2,
#   'banking industry': 2,
#   'operations management': 2,
#   'staffing': 1,
#   'ddd': 1,
#   'supply chain management': 1,
#   'marketing management': 1,
#   'it infrastructure': 1,
#   'event management': 1,
#   'key account management': 1,
#   'c++': 1,
#   'microsoft windows': 1,
#   'microservices architecture': 1,
#   'sea': 1,
#   'business plans': 1,
#   'health': 1,
#   'evaluation': 1,
#   'business administration': 1,
#   'wellness and fitness': 1,
#   'configuration management': 1,
#   'security and protective services': 1,
#   'security management': 1,
#   'scm': 1,
#   'r': 1,
#   'it service management': 1,
#   'private banking': 1,
#   'pmi': 1,
#   'administration and secretariat': 1,
#   'security': 1,
#   'automotive parts': 1,
#   'microsoft office': 1,
#   'microsoft dynamics': 1,
#   'advertising': 1,
#   'cvs': 1,
#   'training': 1,
#   'sap fi': 1,
#   'food and beverages': 1,
#   'banking and real estate': 1,
#   'orchestration': 1,
#   'government': 1,
#   'credit analysis': 1,
#   'asset': 1,
#   'insurance sales': 1,
#   'branch management': 1,
#   'fonds management': 1,
#   'store manager': 1,
#   'tailwind': 1,
#   'react': 1,
#   'teacher': 1,
#   'salesforce.com': 1,
#   'https': 1,
#   'databases': 1,
#   'eplan': 1,
#   'cae': 1,
#   'cad': 1,
#   'b2c': 1,
#   'virtualization': 1,
#   'compliance': 1,
#   'unix': 1,
#   'test driven development': 1,
#   'scalability': 1,
#   'resilience': 1,
#   'product marketing': 1,
#   'investment banking/venture': 1,
#   'cross-selling': 1,
#   'insurance broker': 1,
#   'xml': 1,
#   'logistics planning': 1,
#   'logistics manager': 1,
#   'e-mail marketing': 1,
#   'logistics': 1,
#   'cro': 1,
#   'landing pages': 1,
#   'performance marketing': 1,
#   'payments': 1,
#   'human resource management': 1,
#   'technical consultant': 1,
#   'recruitment': 1,
#   'talent acquisition': 1,
#   'affiliate marketing': 1,
#   'it consulting': 1,
#   'patch management': 1,
#   'installation': 1,
#   'soa': 1,
#   'redis': 1,
#   'php': 1,
#   'electronics': 1,
#   'product manager': 1,
#   'product marketing manager': 1,
#   'database administration': 1,
#   'interior design': 1,
#   'video': 1,
#   'photography': 1,
#   'trade marketing': 1,
#   'mergers & acquisitions': 1,
#   'nosql': 1,
#   'media planning': 1,
#   'computer hardware': 1,
#   'apis': 1,
#   'event-driven architecture': 1,
#   'jest': 1,
#   'mongodb': 1,
#   'mysql': 1,
#   'middleware': 1,
#   'legal counselling': 1,
#   'offline marketing': 1,
#   'ruby': 1,
#   'data quality': 1,
#   'strategic thinking': 1,
#   'visualization': 1,
#   'ansible': 1,
#   'bash': 1,
#   'continuous integration': 1,
#   'debugging': 1,
#   'customer acquisition': 1,
#   'computer science': 1,
#   'sales management': 1,
#   'customer satisfaction': 1,
#   'customer support': 1,
#   'rollout': 1,
#   'technical support': 1,
#   'kanban': 1,
#   'pivot table': 1,
#   'data profiling': 1,
#   'business intelligence': 1,
#   'google search': 1,
#   'high tech': 1,
#   'google tag manager': 1,
#   'management system': 1,
#   'usability': 1,
#   'wordpress': 1,
#   'adobe photoshop': 1,
#   'due diligence': 1,
#   'equity': 1,
#   'private equity': 1,
#   'html5': 1,
#   'sourcing': 1,
#   'venture capital': 1,
#   'coaching': 1,
#   'microsoft powerpoint': 1,
#   'procurement': 1,
#   'growth management': 1,
#   'front end development': 1,
#   '.net core': 1},
#  {'full time': 3240,
#   'permanent': 997,
#   'associate': 829,
#   'entry': 727,
#   'experienced': 680,
#   'part time': 601,
#   'mid-senior': 518,
#   'berufserfahren': 347,
#   'vollzeit (unbefristet)': 166,
#   'berufseinstieg': 121,
#   'apprenticeship': 115,
#   'student': 114,
#   'working student': 107,
#   'internship': 102,
#   'intern/student': 56,
#   'hilfstätigkeit / student': 38,
#   'professional / experienced': 31,
#   'temporary': 27,
#   'intern': 26,
#   'freelance': 25,
#   'teamleitung': 18,
#   'executive': 16,
#   'contract': 16,
#   'teilzeit (unbefristet)': 15,
#   'vollzeit (temporär)': 11,
#   'side': 9,
#   'dual studies': 8,
#   'full-time (permanent)': 7,
#   'traineeship': 6,
#   'marketing': 6,
#   'teilzeit (temporär)': 6,
#   'geschäftsleitung': 5,
#   'senior executive': 5,
#   'director': 5,
#   'accounting and finance': 3,
#   'interim': 3,
#   'software development': 3,
#   'full-time (temporary)': 2,
#   'manager': 2,
#   'no experience required / student': 2,
#   'part-time (temporary)': 1,
#   'customer support and client care': 1,
#   'building construction and skilled trades': 1,
#   'sales': 1,
#   'engineering': 1,
#   'part-time (permanent)': 1})
